# %% [markdown]
# <a href="https://colab.research.google.com/github/Jarnami/PROBABILIDAD-Y-ESTADISTICA-/blob/main/Unidad%201/PRACTICA4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **UNIDAD 1**
# ### **Probabilidad y Estadistica**
#
# ### **Practica: 4**
# ### **Dr. Jose Gabriel Rodriguez Rivas.**
# ### **Alumno: Jatziri Nahomi Morales Rodriguez**

# %% [markdown]
# # **TABLA DE FRECUENCIAS**

# %%
import random

# %%
# basado en el LIBRO estadística para administración pagina 12
# creamos una lista vacia que representa la edad de 100 personas

edades= []

# Hacemos un ciclo para generar 100 números aleatorios que representan la edad de las personas
for i in range(100):
    # generamos un número aleatorio con la funcion randint y lo guardamos en la variable
    # numero_aleatorio
    numero_aleatorio = random.randint( 18, 70)
    # Agregamos el número aleatorio a la lista de valores
    edades.append(numero_aleatorio)

print(edades)
# Out:
# [59, 56, 32, 48, 43, 45, 44, 70, 68, 21, 59, 45, 48, 56, 70, 38, 27, 34, 46, 52, 70, 32, 54, 42, 22, 38, 63, 66, 65, 31, 69, 22, 47, 29, 47, 61, 55, 24, 23, 61, 70, 60, 66, 45, 55, 69, 52, 63, 18, 19, 34, 36, 65, 59, 46, 47, 26, 64, 48, 18, 70, 25, 24, 44, 38, 70, 52, 61, 64, 27, 64, 69, 65, 48, 48, 51, 23, 59, 59, 32, 44, 42, 30, 50, 68, 27, 45, 31, 68, 30, 24, 62, 60, 19, 29, 33, 67, 69, 67, 67]

# %%
import pandas as pd

# %%
# Crear un DataFrame de pandas con los números aleatorios
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    59
# 1    56
# 2    32
# 3    48
# 4    43

# %%
# Calcular la tabla de distribución de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribuciones de frecuencias
print("Tabla de Distribuciones de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribuciones de Frecuencias:
#     Edad  Frecuencia
# 20    18           2
# 19    19           2
# 32    21           1
# 30    22           2
# 22    23           2
# 7     24           3
# 35    25           1
# 34    26           1
# 13    27           3
# 26    29           2
# 18    30           2
# 25    31           2
# 14    32           3
# 40    33           1
# 17    34           2
# 33    36           1
# 15    38           3
# 31    42           2
# 41    43           1
# 12    44           3
# 3     45           4
# 23    46           2
# 9     47           3
# 2     48           5
# 38    50           1
# 36    51           1
# 5     52           3
# 37    54           1
# 24    55           2
# 27    56           2
# 1     59           5
# 21    60           2
# 8     61           3
# 39    62           1
# 29    63           2
# 6     64           3
# 10    65           3
# 28    66           2
# 11    67           3
# 16    68           3
# 4     69           4
# 0     70           6

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 20    18           2           0.02
# 19    19           2           0.02
# 32    21           1           0.01
# 30    22           2           0.02
# 22    23           2           0.02
# 7     24           3           0.03
# 35    25           1           0.01
# 34    26           1           0.01
# 13    27           3           0.03
# 26    29           2           0.02
# 18    30           2           0.02
# 25    31           2           0.02
# 14    32           3           0.03
# 40    33           1           0.01
# 17    34           2           0.02
# 33    36           1           0.01
# 15    38           3           0.03
# 31    42           2           0.02
# 41    43           1           0.01
# 12    44           3           0.03
# 3     45           4           0.04
# 23    46           2           0.02
# 9     47           3           0.03
# 2     48           5           0.05
# 38    50           1           0.01
# 36    51           1           0.01
# 5     52           3           0.03
# 37    54           1           0.01
# 24    55           2           0.02
# 27    56           2           0.02
# 1     59           5           0.05
# 21    60           2           0.02
# 8     61           3           0.03
# 39    62           1           0.01
# 29    63           2           0.02
# 6     64           3           0.03
# 10    65           3           0.03
# 28    66           2           0.02
# 11    67           3           0.03
# 16    68           3           0.03
# 4     69           4           0.04
# 0     70           6           0.06

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 20    18           2           0.02              2.0
# 19    19           2           0.02              2.0
# 32    21           1           0.01              1.0
# 30    22           2           0.02              2.0
# 22    23           2           0.02              2.0
# 7     24           3           0.03              3.0
# 35    25           1           0.01              1.0
# 34    26           1           0.01              1.0
# 13    27           3           0.03              3.0
# 26    29           2           0.02              2.0
# 18    30           2           0.02              2.0
# 25    31           2           0.02              2.0
# 14    32           3           0.03              3.0
# 40    33           1           0.01              1.0
# 17    34           2           0.02              2.0
# 33    36           1           0.01              1.0
# 15    38           3           0.03              3.0
# 31    42           2           0.02              2.0
# 41    43           1           0.01              1.0
# 12    44           3           0.03              3.0
# 3     45           4           0.04              4.0
# 23    46           2           0.02              2.0
# 9     47           3           0.03              3.0
# 2     48           5           0.05              5.0
# 38    50           1           0.01              1.0
# 36    51           1           0.01              1.0
# 5     52           3           0.03              3.0
# 37    54           1           0.01              1.0
# 24    55           2           0.02              2.0
# 27    56           2           0.02              2.0
# 1     59           5           0.05              5.0
# 21    60           2           0.02              2.0
# 8     61           3           0.03              3.0
# 39    62           1           0.01              1.0
# 29    63           2           0.02              2.0
# 6     64           3           0.03              3.0
# 10    65           3           0.03              3.0
# 28    66           2           0.02              2.0
# 11    67           3           0.03              3.0
# 16    68           3           0.03              3.0
# 4     69           4           0.04              4.0
# 0     70           6           0.06              6.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 20    18           2           0.02              2.0               2
# 19    19           2           0.02              2.0               4
# 32    21           1           0.01              1.0               5
# 30    22           2           0.02              2.0               7
# 22    23           2           0.02              2.0               9
# 7     24           3           0.03              3.0              12
# 35    25           1           0.01              1.0              13
# 34    26           1           0.01              1.0              14
# 13    27           3           0.03              3.0              17
# 26    29           2           0.02              2.0              19
# 18    30           2           0.02              2.0              21
# 25    31           2           0.02              2.0              23
# 14    32           3           0.03              3.0              26
# 40    33           1           0.01              1.0              27
# 17    34           2           0.02              2.0              29
# 33    36           1           0.01              1.0              30
# 15    38           3           0.03              3.0              33
# 31    42           2           0.02              2.0              35
# 41    43           1           0.01              1.0              36
# 12    44           3           0.03              3.0              39
# 3     45           4           0.04              4.0              43
# 23    46           2           0.02              2.0              45
# 9     47           3           0.03              3.0              48
# 2     48           5           0.05              5.0              53
# 38    50           1           0.01              1.0              54
# 36    51           1           0.01              1.0              55
# 5     52           3           0.03              3.0              58
# 37    54           1           0.01              1.0              59
# 24    55           2           0.02              2.0              61
# 27    56           2           0.02              2.0              63
# 1     59           5           0.05              5.0              68
# 21    60           2           0.02              2.0              70
# 8     61           3           0.03              3.0              73
# 39    62           1           0.01              1.0              74
# 29    63           2           0.02              2.0              76
# 6     64           3           0.03              3.0              79
# 10    65           3           0.03              3.0              82
# 28    66           2           0.02              2.0              84
# 11    67           3           0.03              3.0              87
# 16    68           3           0.03              3.0              90
# 4     69           4           0.04              4.0              94
# 0     70           6           0.06              6.0             100

# %% [markdown]
# # **Regla de sturges**
# 1.- Es una regla que sirve para calcular el número de clases o intervalos idóneos en los que que se debe dividir un conjunto de datos.
# 2.Establece que  **el número de clases es igual a uno más el logaritmo en base dos del número total de datos.**
#
# ** * C= 1 + log²(N)* **
#
# Donde N es el tamaño de la muestra.

# %%
import math

# %%
# Volvemos a usar la lista de edades
print (edades)
# Out:
# [59, 56, 32, 48, 43, 45, 44, 70, 68, 21, 59, 45, 48, 56, 70, 38, 27, 34, 46, 52, 70, 32, 54, 42, 22, 38, 63, 66, 65, 31, 69, 22, 47, 29, 47, 61, 55, 24, 23, 61, 70, 60, 66, 45, 55, 69, 52, 63, 18, 19, 34, 36, 65, 59, 46, 47, 26, 64, 48, 18, 70, 25, 24, 44, 38, 70, 52, 61, 64, 27, 64, 69, 65, 48, 48, 51, 23, 59, 59, 32, 44, 42, 30, 50, 68, 27, 45, 31, 68, 30, 24, 62, 60, 19, 29, 33, 67, 69, 67, 67]

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     59
# 1     56
# 2     32
# 3     48
# 4     43
# ..   ...
# 95    33
# 96    67
# 97    69
# 98    67
# 99    67
#
# [100 rows x 1 columns]

# %%
# Calcular el número de intervalos utilizando la regla de Sturges
n = len(edades)
k = int( 1 + math.log2(100))
print("Valor de n = ", n , " \nNúmero de intervalos =", k)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
# Crear la tabla de frecuencias

tabla_frecuencia = pd.cut( df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0    (62.571, 70.0]    26
# 1  (40.286, 47.714]    15
# 2  (17.947, 25.429]    13
# 3  (25.429, 32.857]    13
# 4  (47.714, 55.143]    13
# 5  (55.143, 62.571]    13
# 6  (32.857, 40.286]     7

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 2  (17.947, 25.429]    13
# 3  (25.429, 32.857]    13
# 6  (32.857, 40.286]     7
# 1  (40.286, 47.714]    15
# 4  (47.714, 55.143]    13
# 5  (55.143, 62.571]    13
# 0    (62.571, 70.0]    26

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 2  (17.947, 25.429]    13      0.13       13.0       13         0.13
# 3  (25.429, 32.857]    13      0.13       13.0       26         0.26
# 6  (32.857, 40.286]     7      0.07        7.0       33         0.33
# 1  (40.286, 47.714]    15      0.15       15.0       48         0.48
# 4  (47.714, 55.143]    13      0.13       13.0       61         0.61
# 5  (55.143, 62.571]    13      0.13       13.0       74         0.74
# 0    (62.571, 70.0]    26      0.26       26.0      100         1.00
#
#    Frec Porc Ac
# 2          13.0
# 3          26.0
# 6          33.0
# 1          48.0
# 4          61.0
# 5          74.0
# 0         100.0
