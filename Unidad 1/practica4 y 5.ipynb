# %% [markdown]
# <a href="https://colab.research.google.com/github/Jarnami/PROBABILIDAD-Y-ESTADISTICA-/blob/main/Unidad%201/practica4%20y%205.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **UNIDAD 1**
# ### **Probabilidad y Estadistica**
#
# ### **Practica: 4-Tabla de frecuencias y regla de Sturges.**
# ### **Dr. Jose Gabriel Rodriguez Rivas.**
# ### **Alumno: Jatziri Nahomi Morales Rodriguez**

# %% [markdown]
# # **TABLA DE FRECUENCIAS**

# %%
import random

# %%
# basado en el LIBRO estadística para administración pagina 12
# creamos una lista vacia que representa la edad de 100 personas

edades= []

# Hacemos un ciclo para generar 100 números aleatorios que representan la edad de las personas
for i in range(100):
    # generamos un número aleatorio con la funcion randint y lo guardamos en la variable
    # numero_aleatorio
    numero_aleatorio = random.randint( 18, 70)
    # Agregamos el número aleatorio a la lista de valores
    edades.append(numero_aleatorio)

print(edades)
# Out:
# [67, 69, 69, 47, 54, 28, 62, 37, 50, 33, 51, 23, 68, 49, 44, 43, 61, 33, 37, 68, 38, 29, 39, 26, 24, 59, 33, 37, 69, 44, 32, 25, 46, 56, 41, 50, 59, 66, 38, 41, 38, 68, 53, 20, 50, 18, 61, 61, 21, 64, 52, 23, 33, 66, 44, 22, 31, 22, 25, 26, 41, 35, 65, 52, 43, 42, 65, 37, 63, 41, 62, 57, 66, 54, 41, 28, 32, 63, 26, 37, 18, 60, 37, 57, 34, 58, 65, 42, 51, 56, 56, 70, 53, 66, 54, 42, 54, 43, 24, 28]

# %%
import pandas as pd

# %%
# Crear un DataFrame de pandas con los números aleatorios
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    67
# 1    69
# 2    69
# 3    47
# 4    54

# %%
# Calcular la tabla de distribución de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribuciones de frecuencias
print("Tabla de Distribuciones de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribuciones de Frecuencias:
#     Edad  Frecuencia
# 19    18           2
# 38    20           1
# 37    21           1
# 23    22           2
# 27    23           2
# 25    24           2
# 18    25           2
# 8     26           3
# 16    28           3
# 41    29           1
# 30    31           1
# 22    32           2
# 4     33           4
# 31    34           1
# 32    35           1
# 0     37           6
# 9     38           3
# 40    39           1
# 1     41           5
# 13    42           3
# 11    43           3
# 6     44           3
# 39    46           1
# 43    47           1
# 42    49           1
# 14    50           3
# 28    51           2
# 20    52           2
# 17    53           2
# 2     54           4
# 7     56           3
# 26    57           2
# 33    58           1
# 24    59           2
# 34    60           1
# 10    61           3
# 29    62           2
# 21    63           2
# 36    64           1
# 15    65           3
# 3     66           4
# 35    67           1
# 5     68           3
# 12    69           3
# 44    70           1

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 19    18           2           0.02
# 38    20           1           0.01
# 37    21           1           0.01
# 23    22           2           0.02
# 27    23           2           0.02
# 25    24           2           0.02
# 18    25           2           0.02
# 8     26           3           0.03
# 16    28           3           0.03
# 41    29           1           0.01
# 30    31           1           0.01
# 22    32           2           0.02
# 4     33           4           0.04
# 31    34           1           0.01
# 32    35           1           0.01
# 0     37           6           0.06
# 9     38           3           0.03
# 40    39           1           0.01
# 1     41           5           0.05
# 13    42           3           0.03
# 11    43           3           0.03
# 6     44           3           0.03
# 39    46           1           0.01
# 43    47           1           0.01
# 42    49           1           0.01
# 14    50           3           0.03
# 28    51           2           0.02
# 20    52           2           0.02
# 17    53           2           0.02
# 2     54           4           0.04
# 7     56           3           0.03
# 26    57           2           0.02
# 33    58           1           0.01
# 24    59           2           0.02
# 34    60           1           0.01
# 10    61           3           0.03
# 29    62           2           0.02
# 21    63           2           0.02
# 36    64           1           0.01
# 15    65           3           0.03
# 3     66           4           0.04
# 35    67           1           0.01
# 5     68           3           0.03
# 12    69           3           0.03
# 44    70           1           0.01

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 19    18           2           0.02              2.0
# 38    20           1           0.01              1.0
# 37    21           1           0.01              1.0
# 23    22           2           0.02              2.0
# 27    23           2           0.02              2.0
# 25    24           2           0.02              2.0
# 18    25           2           0.02              2.0
# 8     26           3           0.03              3.0
# 16    28           3           0.03              3.0
# 41    29           1           0.01              1.0
# 30    31           1           0.01              1.0
# 22    32           2           0.02              2.0
# 4     33           4           0.04              4.0
# 31    34           1           0.01              1.0
# 32    35           1           0.01              1.0
# 0     37           6           0.06              6.0
# 9     38           3           0.03              3.0
# 40    39           1           0.01              1.0
# 1     41           5           0.05              5.0
# 13    42           3           0.03              3.0
# 11    43           3           0.03              3.0
# 6     44           3           0.03              3.0
# 39    46           1           0.01              1.0
# 43    47           1           0.01              1.0
# 42    49           1           0.01              1.0
# 14    50           3           0.03              3.0
# 28    51           2           0.02              2.0
# 20    52           2           0.02              2.0
# 17    53           2           0.02              2.0
# 2     54           4           0.04              4.0
# 7     56           3           0.03              3.0
# 26    57           2           0.02              2.0
# 33    58           1           0.01              1.0
# 24    59           2           0.02              2.0
# 34    60           1           0.01              1.0
# 10    61           3           0.03              3.0
# 29    62           2           0.02              2.0
# 21    63           2           0.02              2.0
# 36    64           1           0.01              1.0
# 15    65           3           0.03              3.0
# 3     66           4           0.04              4.0
# 35    67           1           0.01              1.0
# 5     68           3           0.03              3.0
# 12    69           3           0.03              3.0
# 44    70           1           0.01              1.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 19    18           2           0.02              2.0               2
# 38    20           1           0.01              1.0               3
# 37    21           1           0.01              1.0               4
# 23    22           2           0.02              2.0               6
# 27    23           2           0.02              2.0               8
# 25    24           2           0.02              2.0              10
# 18    25           2           0.02              2.0              12
# 8     26           3           0.03              3.0              15
# 16    28           3           0.03              3.0              18
# 41    29           1           0.01              1.0              19
# 30    31           1           0.01              1.0              20
# 22    32           2           0.02              2.0              22
# 4     33           4           0.04              4.0              26
# 31    34           1           0.01              1.0              27
# 32    35           1           0.01              1.0              28
# 0     37           6           0.06              6.0              34
# 9     38           3           0.03              3.0              37
# 40    39           1           0.01              1.0              38
# 1     41           5           0.05              5.0              43
# 13    42           3           0.03              3.0              46
# 11    43           3           0.03              3.0              49
# 6     44           3           0.03              3.0              52
# 39    46           1           0.01              1.0              53
# 43    47           1           0.01              1.0              54
# 42    49           1           0.01              1.0              55
# 14    50           3           0.03              3.0              58
# 28    51           2           0.02              2.0              60
# 20    52           2           0.02              2.0              62
# 17    53           2           0.02              2.0              64
# 2     54           4           0.04              4.0              68
# 7     56           3           0.03              3.0              71
# 26    57           2           0.02              2.0              73
# 33    58           1           0.01              1.0              74
# 24    59           2           0.02              2.0              76
# 34    60           1           0.01              1.0              77
# 10    61           3           0.03              3.0              80
# 29    62           2           0.02              2.0              82
# 21    63           2           0.02              2.0              84
# 36    64           1           0.01              1.0              85
# 15    65           3           0.03              3.0              88
# 3     66           4           0.04              4.0              92
# 35    67           1           0.01              1.0              93
# 5     68           3           0.03              3.0              96
# 12    69           3           0.03              3.0              99
# 44    70           1           0.01              1.0             100

# %% [markdown]
# # **Regla de sturges**
# 1.- Es una regla que sirve para calcular el número de clases o intervalos idóneos en los que que se debe dividir un conjunto de datos.
# 2.Establece que  **el número de clases es igual a uno más el logaritmo en base dos del número total de datos.**
#
# ** * C= 1 + log²(N)* **
#
# Donde N es el tamaño de la muestra.

# %%
import math

# %%
# Volvemos a usar la lista de edades
print (edades)
# Out:
# [67, 69, 69, 47, 54, 28, 62, 37, 50, 33, 51, 23, 68, 49, 44, 43, 61, 33, 37, 68, 38, 29, 39, 26, 24, 59, 33, 37, 69, 44, 32, 25, 46, 56, 41, 50, 59, 66, 38, 41, 38, 68, 53, 20, 50, 18, 61, 61, 21, 64, 52, 23, 33, 66, 44, 22, 31, 22, 25, 26, 41, 35, 65, 52, 43, 42, 65, 37, 63, 41, 62, 57, 66, 54, 41, 28, 32, 63, 26, 37, 18, 60, 37, 57, 34, 58, 65, 42, 51, 56, 56, 70, 53, 66, 54, 42, 54, 43, 24, 28]

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     67
# 1     69
# 2     69
# 3     47
# 4     54
# ..   ...
# 95    42
# 96    54
# 97    43
# 98    24
# 99    28
#
# [100 rows x 1 columns]

# %%
# Calcular el número de intervalos utilizando la regla de Sturges
n = len(edades)
k = int( 1 + math.log2(100))
print("Valor de n = ", n , " \nNúmero de intervalos =", k)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
# Crear la tabla de frecuencias

tabla_frecuencia = pd.cut( df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0    (62.571, 70.0]    18
# 1  (32.857, 40.286]    16
# 2  (40.286, 47.714]    16
# 3  (47.714, 55.143]    14
# 4  (55.143, 62.571]    14
# 5  (17.947, 25.429]    12
# 6  (25.429, 32.857]    10

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 5  (17.947, 25.429]    12
# 6  (25.429, 32.857]    10
# 1  (32.857, 40.286]    16
# 2  (40.286, 47.714]    16
# 3  (47.714, 55.143]    14
# 4  (55.143, 62.571]    14
# 0    (62.571, 70.0]    18

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 5  (17.947, 25.429]    12      0.12       12.0       12         0.12
# 6  (25.429, 32.857]    10      0.10       10.0       22         0.22
# 1  (32.857, 40.286]    16      0.16       16.0       38         0.38
# 2  (40.286, 47.714]    16      0.16       16.0       54         0.54
# 3  (47.714, 55.143]    14      0.14       14.0       68         0.68
# 4  (55.143, 62.571]    14      0.14       14.0       82         0.82
# 0    (62.571, 70.0]    18      0.18       18.0      100         1.00
#
#    Frec Porc Ac
# 5          12.0
# 6          22.0
# 1          38.0
# 2          54.0
# 3          68.0
# 4          82.0
# 0         100.0

# %%
import matplotlib.pyplot as plt #impor
plt.hist(edades, alpha = 0.5)
plt.title("Historama de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Historama de edades basado en la funcion de matplotlib con valores estandar')

# %%
#crear un historama basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=k, alpha = 0.5)
plt.title("Historama de edades basado en la regla de Struges")
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# # **PRACTICA 5: DIAGRAMA DE CAJAS Y BIGOTES**

# %%
# basado en el LIBRO estadística para administración pagina 12
# creamos una lista vacia que representa la edad de 100 personas

edades2= []

# Hacemos un ciclo para generar 100 números aleatorios que representan la edad de las personas
for i in range(100):
    # generamos un número aleatorio con la funcion randint y lo guardamos en la variable
    # numero_aleatorio
    numero_aleatorio = random.randint( 20, 87)
    # Agregamos el número aleatorio a la lista de valores
    edades2.append(numero_aleatorio)

print(edades2)
# Out:
# [57, 87, 78, 84, 25, 22, 26, 47, 86, 57, 22, 37, 29, 48, 30, 54, 74, 40, 66, 53, 86, 30, 33, 23, 51, 75, 69, 72, 69, 48, 44, 86, 79, 23, 44, 34, 27, 47, 75, 60, 23, 87, 45, 36, 43, 22, 38, 43, 71, 66, 21, 37, 22, 53, 21, 24, 32, 75, 80, 38, 52, 38, 55, 53, 44, 64, 29, 40, 29, 77, 21, 66, 53, 26, 58, 68, 54, 35, 26, 43, 66, 86, 32, 63, 68, 57, 45, 47, 76, 44, 58, 27, 38, 38, 61, 74, 27, 65, 55, 29]

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1 = ax1.boxplot(edades,
                     vert=True, #vertical box aligment
                     patch_artist=True) #fill with color
ax1.set_title("Edades Encuesta 1 ")

bplot2 = ax2.boxplot(edades2,
                         vert=True, #vertical box aligment
                     patch_artist=True) #fill with color
ax2.set_title("Edades Encuesta 2 ")
plt.show()

# %%
edades2.append(130)

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1 = ax1.boxplot(edades,
                     vert=True, #vertical box aligment
                     patch_artist=True) #fill with color
ax1.set_title("Edades Encuesta 1 ")

bplot2 = ax2.boxplot(edades2,
                         vert=True, #vertical box aligment
                     patch_artist=True) #fill with color
ax2.set_title("Edades Encuesta 2 ")
plt.show()

# %% [markdown]
# # **CONCLUSIONES**
