# %% [markdown]
# <a href="https://colab.research.google.com/github/Jarnami/PROBABILIDAD-Y-ESTADISTICA-/blob/main/Unidad%204/Distribucion%20normal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **UNIDAD 4**
# ### **Practica 1**
# ### **DISTRIBUCION NORMAL**
#
# ## Facilitador: Jose Gabriel Rivas
# ## Alumno: Jatziri Nahomi Morales Rodriguez
#
# ## **Aplicar variables aleatorias continuas, (Numero finito de valores).**

# %% [markdown]
# # **Ejercicio 1**
# Una revision de los pesos de 500 estudiantes del ITD, evidenció que la media es de 70 kilogramos y la desviacion estandar es de 4 kilogramos. Suponiendo que los valores se distribuyen normalmente. Hallar lo siguiente:
#
# Generar aleatoriamente las edades de los 500 estudiantes con una media de 70 kg y una desviacion estandar de 4kg.
#
# Realizar un historama de las edades.
#
# Graficar la funcion de densidad de probabilidad(PDF)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
#Generar datos para la distribucion normal

media = 70 #Media
desv_std = 4 #Desviacion estandar
num_datos =500

#Generamos los datos de manera aleatoria y los ponemos en una lista (array)
datos= np.random.normal(media, desv_std, num_datos)
datos[0:50] #Mostrar los primeros 50
# Out:
# array([62.87910022, 65.81004827, 70.16808009, 75.53270487, 75.48687289,
#        65.63758805, 73.39995248, 69.05039103, 69.89600396, 68.40194986,
#        68.99365088, 68.9892057 , 68.70180659, 66.31779315, 62.47525473,
#        60.91469105, 67.15951551, 70.25519299, 76.25412961, 73.98076465,
#        74.34619702, 72.1722053 , 67.22624689, 64.96033656, 73.02705173,
#        75.9309616 , 78.37243891, 67.85380466, 71.65136111, 74.50996557,
#        76.82752071, 74.52004155, 66.42052356, 63.16792909, 70.59777359,
#        70.585165  , 70.85131796, 66.37976955, 73.74658093, 72.6784675 ,
#        64.18337265, 63.80814279, 67.68955746, 68.54147499, 67.47064621,
#        67.83889741, 74.44481882, 76.77710076, 71.06679873, 62.39572293])

# %%
#Crear un rango de valores para crear una densidad
x = np.linspace(media - 3 * desv_std, media + 3 * desv_std, num_datos)

#Calculas la pdf de la distribucion normal
pdf=1/ desv_std * np.sqrt(2 * np.pi) * np.exp(-(x - media) **2 / (2 * desv_std **2))

# %%
#Para no imprimir toda la lista de valores (500), desplegamos los primeros 50

print("Imprimir los primero 50 valores de x",x[0:50],", Y los primero 50 valores de pdf",pdf[0:50])
# Out:
# Imprimir los primero 50 valores de x [58.         58.04809619 58.09619238 58.14428858 58.19238477 58.24048096
#  58.28857715 58.33667335 58.38476954 58.43286573 58.48096192 58.52905812
#  58.57715431 58.6252505  58.67334669 58.72144289 58.76953908 58.81763527
#  58.86573146 58.91382766 58.96192385 59.01002004 59.05811623 59.10621242
#  59.15430862 59.20240481 59.250501   59.29859719 59.34669339 59.39478958
#  59.44288577 59.49098196 59.53907816 59.58717435 59.63527054 59.68336673
#  59.73146293 59.77955912 59.82765531 59.8757515  59.9238477  59.97194389
#  60.02004008 60.06813627 60.11623246 60.16432866 60.21242485 60.26052104
#  60.30861723 60.35671343] , Y los primero 50 valores de pdf [0.00696153 0.00721671 0.00748016 0.00775211 0.00803279 0.00832242
#  0.00862125 0.00892952 0.00924747 0.00957536 0.00991345 0.01026198
#  0.01062124 0.01099148 0.01137299 0.01176603 0.0121709  0.01258788
#  0.01301726 0.01345935 0.01391443 0.01438283 0.01486484 0.01536079
# ...

# %%
#Graficar historama
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, density=True, color='b')

plt.title('Distribucion normal')
plt.xlabel('Peso (kg)De los estudiantes')
plt.grid(True)
plt.show()

# %%
# visualizar la PDF
plt.figure(figsize=(6,4))
plt.plot(x, pdf, label='normal:(media:{};ds:{})'.format(np.round(media,2), np.round(desv_std,2)))
plt.title('Funcion de densidad de probabilidad (PDF)- Distribucion normal')
plt.xlabel('Peso (kg)De los estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Graficar Histograma
plt.figure(figsize=(6,4))
plt.hist(datos, bins=15, alpha=0.4, density=True, color='b')

plt.title('Distribucion normal')
plt.xlabel('Peso (kg)De los estudiantes')
plt.grid(True)
plt.show()

# %% [markdown]
# # **Ejercicio 2**
# Una revision de los pesos de 500 estudiantes del ITD, evidencio que la media es de 70 kilogramos y la desviacion estandar es de 4 kilogramos. Suponiendo que los valores se distribuyen normalmente.
#
# Cuantos estudiantes pesan menos de 75 kg.
# Cuantos estudiantes oesan menos de 62 kg.
# Cuantos estudiantes pesan mas de 79 kg.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
plt.figure(figsize=(6,4))
#Parametros de distribucion normal
media = 70
desv_std = 4 #Desviaicon estandar
total_estudiantes = 500

#Variable para el calculo de la probabilidad de que un estudiante pese menos de 75kg
peso_limite = 79

#Calcular la probabilidad de que un estudiante pese menos
# de 75 kg utilizando la funcion de distribucion acumulativa (CDF) de la distribucion normal
prob_menos_75kg=norm.cdf(peso_limite, media, desv_std )

# %%
#calcular el numero de estudiantes
num_estudiantes_75kg = prob_menos_75kg * total_estudiantes

print("Probabilidad de que los estudiantes pesen menos de 75kg", prob_menos_75kg)
print("Numero de estudiantes que pesan menos de 75kg", num_estudiantes_75kg)


# graficar
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, 100)
y = stats.norm.pdf(x, media, desv_std)

plt.plot(x, y, label='Distribución Normal')
plt.axvline(peso_limite, color='red', linestyle='--', label='Peso Limite')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de Probabilidad')
plt.title('Distribución Normal de Pesos de Estudiantes')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Probabilidad de que los estudiantes pesen menos de 75kg 0.9877755273449553
# Numero de estudiantes que pesan menos de 75kg 493.88776367247766

# %%
#Cuanto estudiantes pesan mendo de 62kg
plt.figure(figsize=(6,4))

#Parametros de la distribucion normal
media = 70
desv_std = 4
total_estudiantes = 500

#Variable para calculo de la probabilidad que un estudiante pese menos de 75kg
peso_limite = 62

#Necesitamos calculas la probabilidad de que un estudiante pese menos de 75kg utilizando la funcion de distribucion
# acumulativa (CDF) de la distribucion normal
prob_menos_62kg = stats.norm.cdf(peso_limite, media, desv_std)

#Calculo del numero de estudiantes que pesan menos de  75 kg
estudiantes_menos_62kg = prob_menos_62kg * total_estudiantes

print("Probabilidad de que los estudiantes pesen menos de 62kg", prob_menos_62kg)
print("Numero de estudiantes que pesan menos de 75kg", estudiantes_menos_62kg)
# Out:
# Probabilidad de que los estudiantes pesen menos de 62kg 0.022750131948179195
# Numero de estudiantes que pesan menos de 75kg 11.375065974089598

# %%
#Calcular la distribucion normal
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = stats.norm.pdf(x, media, desv_std)

#Graficar la distribucion normal
plt.plot(x, y, "b", linewidth=2)
plt.fill_between(x, y, where=(x <= peso_limite), color="skyblue", alpha=0.5)
plt.title("Probabilidad de que un estudiante pese menos de 62 kg,")
plt.xlabel("Peso (kg)")
plt.ylabel("Densidad de Probabilidad")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,4))

media = 70
desv_std = 4
peso_limite = 79
total_estudiantes = 500

#Probavbilidad de que un estudiante pese menos o igual a 79kg
prob_menos_79kg = stats.norm.cdf(peso_limite, media, desv_std)

#Probabilidad de que un estudiante pese menos o igual a 79kg
prob_menos_79kg = 1 -prob_menos_79kg

#Calculamos el numero aproimado de estudiantes que pesan mas de 79kg
num_estudiantes_79kg = prob_menos_79kg * total_estudiantes

print("probabilidad de que los estudiantes pesen menos de 79kg", prob_menos_79kg)
print("numero de estudiantes que pesan menos de 79kg", num_estudiantes_79kg)
# Out:
# probabilidad de que los estudiantes pesen menos de 79kg 0.012224472655044671
# numero de estudiantes que pesan menos de 79kg 6.112236327522336

# %%
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x >= peso_limite), color='skyblue', alpha=0.5)
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de Probabilidad')
plt.title('Prbabilidad de que un estudiante pese mas de 79kg')

plt.grid(True)
plt.show()
